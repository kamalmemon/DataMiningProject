# %%
import numpy
from matplotlib import pyplot as plt

# %%
plt.plot([10000,25000,40000,100000], [4.4017,4.4056, 4.4108,4.4032], marker='o', label='Approx. values')
plt.xlabel('Accuracy paramter')
plt.ylabel('Mean')
plt.axhline(4.4048, color='r', label='Exact value')
plt.title('Approximation of LSCC by random pairs - MEAN')
plt.legend()
plt.show()

# %%
plt.plot([10000,25000,40000,100000], [4.5229,4.4066,4.4529,4.4147], marker='o', label='Approx. values')
plt.xlabel('Accuracy paramter')
plt.ylabel('Mean')
plt.axhline(4.4536, color='r', label='Exact value')
plt.title('Approximation of LWCC by random pairs - MEAN')
plt.legend()
plt.show()

# %%
plt.plot([10,25,40,50], [4.2664,4.3584,4.3371,4.4145], marker='o', label='Approx. values')
plt.xlabel('No. of random sources')
plt.ylabel('Mean')
plt.axhline(4.4048, color='r', label='Exact value')
plt.title('Approximation of LSCC by random sources - MEAN')
plt.legend()
plt.show()

# %%
plt.plot([10,25,40,50], [4.0817,4.1085,4.4059,4.3638], marker='o', label='Approx. values')
plt.xlabel('No. of random sources')
plt.ylabel('Mean')
plt.axhline(4.4536, color='r', label='Exact value')
plt.title('Approximation of LWCC by random sources - MEAN')
plt.legend()
plt.show()

# %%
plt.plot([256,512,768,1024], [3.6905,3.6832,3.6084,3.6891], marker='o', label='Approx. values')
plt.xlabel('Value of k')
plt.ylabel('Mean')
plt.axhline(4.4048, color='r', label='Exact value')
plt.title('Approximation of LSCC by ANF - MEAN')
plt.legend()
plt.show()

# %%
plt.plot([256,512,768,1024], [4.0851,4.1307,4.3234,4.5100], marker='o', label='Approx. values')
plt.xlabel('Value of k')
plt.ylabel('Mean')
plt.axhline(4.4536, color='r', label='Exact value')
plt.title('Approximation of LWCC by ANF - MEAN')
plt.legend()
plt.show()
